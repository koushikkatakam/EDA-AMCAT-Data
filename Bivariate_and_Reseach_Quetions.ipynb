# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns

# %%
df = pd.read_csv('final_cleaned_data.csv')

# %%
df
# Out:
#       Unnamed: 0      ID    Salary         DOJ                  DOL  \
# 0              0  203097  420000.0  2012-06-01              present
# 1              1  579905  500000.0  2013-09-01              present
# 2              2  810601  325000.0  2014-06-01              present
# 3              3  267447  300000.0  2011-07-01              present
# 4              4  343523  200000.0  2014-03-01  2015-03-01 00:00:00
# ...          ...     ...       ...         ...                  ...
# 3993        3993   47916  280000.0  2011-10-01  2012-10-01 00:00:00
# 3994        3994  752781  100000.0  2013-07-01  2013-07-01 00:00:00
# 3995        3995  355888  320000.0  2013-07-01              present
# 3996        3996  947111  200000.0  2014-07-01  2015-01-01 00:00:00
# 3997        3997  324966  400000.0  2013-02-01              present
#
#                       Designation           JobCity Gender         DOB  \
# 0         senior quality engineer         Bangalore      f  1990-02-19
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df
# Out:
#           ID    Salary         DOJ                  DOL  \
# 0     203097  420000.0  2012-06-01              present
# 1     579905  500000.0  2013-09-01              present
# 2     810601  325000.0  2014-06-01              present
# 3     267447  300000.0  2011-07-01              present
# 4     343523  200000.0  2014-03-01  2015-03-01 00:00:00
# ...      ...       ...         ...                  ...
# 3993   47916  280000.0  2011-10-01  2012-10-01 00:00:00
# 3994  752781  100000.0  2013-07-01  2013-07-01 00:00:00
# 3995  355888  320000.0  2013-07-01              present
# 3996  947111  200000.0  2014-07-01  2015-01-01 00:00:00
# 3997  324966  400000.0  2013-02-01              present
#
#                       Designation           JobCity Gender         DOB  \
# 0         senior quality engineer         Bangalore      f  1990-02-19
# 1               assistant manager            Indore      m  1989-10-04
# 2                 system engineer           Chennai      f  1992-08-03
# ...

# %%
df.describe()
# Out:
#                  ID         Salary  10percentage  12graduation  12percentage  \
# count  3.998000e+03    3998.000000   3998.000000   3998.000000   3998.000000
# mean   6.637945e+05  285843.921961     78.157261   2008.150075     74.474970
# std    3.632182e+05  124800.073901      9.504863      1.522737     10.986412
# min    1.124400e+04   35000.000000     51.000000   2004.000000     43.000000
# 25%    3.342842e+05  180000.000000     72.000000   2007.000000     66.000000
# 50%    6.396000e+05  300000.000000     79.155000   2008.000000     74.400000
# 75%    9.904800e+05  355000.000000     85.670000   2009.000000     82.600000
# max    1.298275e+06  655000.000000     97.760000   2012.000000     98.700000
#
#           CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  \
# count   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000
# mean    5156.851426     1.925713    71.573032    5156.851426         0.300400
# ...

# %% [markdown]
# ### Salary Column i.e Target Variable after cleaning

# %%
sns.boxplot(df['Salary'])
# Out:
# <Axes: ylabel='Salary'>

# %% [markdown]
# - Most of the employed members salary is between 1.8lac to 3.8lac

# %% [markdown]
# ### Bivariate Num vs Num(Target Variable vs other numerical variable)

# %%
numerical_cols = ['Salary', '10percentage', '12graduation', '12percentage', 
                  'collegeGPA', 'conscientiousness', 'agreeableness', 
                  'extraversion', 'nueroticism', 'openess_to_experience']
numerical_cols
# Out:
# ['Salary',
#  '10percentage',
#  '12graduation',
#  '12percentage',
#  'collegeGPA',
#  'conscientiousness',
#  'agreeableness',
#  'extraversion',
#  'nueroticism',
#  'openess_to_experience']

# %% [markdown]
# ### Employees with which 10th percentage have more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['10percentage'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and 10percentage')
plt.xlabel('10percentage')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %% [markdown]
# - The Candidates with 50 to 60 10th percentage have rarely 5 to 6lac salary and most of them have salary with this percentage between 1 to 4.5lac.
# - The Candidates with 90 to 98 10th percentage have 5 to 6lac salary.
# - The candidates with 70 to 90 10th percentage have 3 to 4.5 lac salary.

# %% [markdown]
# ### Employees with which 12th graduation year have more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['12graduation'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and 12graduation')
plt.xlabel('12graduation')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - 2004 to 2010 12th graduation students have packages from 1lac to 6lac.
# - 2012 graduation students are rarely got job that means data may not be there or who are 2012 12th passedout students are not employed in software industry

# %% [markdown]
# ### Employees with which 12th percentage have more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['12percentage'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and 12percentage')
plt.xlabel('12percentage')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - 12th class percentage of 60 to 90 have atmost packages between 3lac to 4lac and they have upto 6 lac package also.
# - 12th class percentage of 50 to 60 have atmost 1lac to 3lac package and rarely they got above 4lac package

# %% [markdown]
# ### Employees with which CGPA have more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['collegeGPA'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and collegeGPA')
plt.xlabel('collegeGPA')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - who have 50 to 60 Degree Percentage have got rarely above 4lac package.
# - who have 60 to 85 Degree percentage have got package from 1lac to 4lac and rarely 5 to 6lac package

# %% [markdown]
# ### Employees with which conscientiousness have more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['conscientiousness'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and conscientiousness')
plt.xlabel('conscientiousness')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - Mostly who have positive conscientiousness are having good salary package.
# - Rarely who have negative conscientiousness have good salary package

# %% [markdown]
# ### Employees with which agreebleness have more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['agreeableness'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and agreeableness')
plt.xlabel('agreeableness')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - who are positive agreeblenesss have good amount of salary package.
# - who are not agreed they do have good salary but rarely,only some people are with good salary.

# %% [markdown]
# ### Employees with which extraversion having more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['extraversion'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and extraversion')
plt.xlabel('extraversion')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - who are positive extraversion have good amount of salary package.
# - who dont have extraversion they do have good salary but rarely,only some people are with good salary.

# %% [markdown]
# ### Employees with which nueroticium having more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['nueroticism'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and nueroticism')
plt.xlabel('nueroticism')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - who are positive nueroticism have good amount of salary package.
# - who donot have nueroticism they do have good salary but rarely,only some people are with good salary.

# %% [markdown]
# ### Employees with which experience having more salaries?

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['openess_to_experience'],df['Salary'], color='skyblue', alpha=0.7)
plt.title('Relationship between Salary and openess_to_experience')
plt.xlabel('openess_to_experience')
plt.ylabel('Salary')
# plt.grid(True)
plt.show()

# %% [markdown]
# - who have they have almost good salaries.
# - who dont have experience they do have good salaries but rarely.

# %% [markdown]
# ### Bivariate Num vs cat(Target Variable vs other categorical variable)

# %% [markdown]
# ### Employees with  which role having more salaries?

# %%
top_ten_designations = df['Designation'].value_counts().head(10).index

filtered_df = df[df['Designation'].isin(top_ten_designations)]
plt.figure(figsize=(24, 8))

sns.boxplot(x='Designation', y='Salary', data=filtered_df)

plt.xlabel('Designation')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 10 Designations')

plt.show()

# %% [markdown]
# - Employees with Designation of senior software engineer have more salaries followed by system engineer.
# - Employees with Designation of technical support engineer have less salaries.

# %% [markdown]
# ### which city of employees are with more salaries?

# %%
top_ten_JobCity = df['JobCity'].value_counts().head(10).index

filtered_df = df[df['JobCity'].isin(top_ten_JobCity)]

plt.figure(figsize=(24, 8))

sns.boxplot(x='JobCity', y='Salary', data=filtered_df)

plt.xlabel('JobCity')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 10 Job Cities')

plt.show()

# %% [markdown]
# - Employees who are in Mumbai and Bangalore having highest salaries.
# - Employees who are in New Delhi and kolkata have less salaries

# %% [markdown]
# ### which gender having more salaries?

# %%
plt.figure(figsize=(24, 8))

sns.boxplot(x='Gender', y='Salary', data=filtered_df)

plt.xlabel('Gender')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Gender')

plt.show()

# %% [markdown]
# - Male and Female have same range of salaries

# %% [markdown]
# ### Which 10th board of employees have more salaries?

# %%
top_ten_10board = df['10board'].value_counts().head(10).index

filtered_df = df[df['10board'].isin(top_ten_10board)]

plt.figure(figsize=(24, 8))

sns.boxplot(x='10board', y='Salary', data=filtered_df)

plt.xlabel('10board')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by top 10 10board')

plt.show()

# %% [markdown]
# - Employees who studied 10th in ssc board are with highest salaries
# - Employeesn who studied in up have less salaries

# %% [markdown]
# ### Which 12t board of employees are with highest salaries?

# %%
top_ten_12board = df['12board'].value_counts().head(10).index

filtered_df = df[df['12board'].isin(top_ten_12board)]

plt.figure(figsize=(24, 8))

sns.boxplot(x='12board', y='Salary', data=filtered_df)

plt.xlabel('12board')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 10 12board')

plt.show()

# %% [markdown]
# - Employees who studied in ise and mp_board having good salaries.
# - Employees who studied in state board having less salaries

# %% [markdown]
# ### Which Degree of employees having highest salaries?

# %%
plt.figure(figsize=(24, 8))

sns.boxplot(x='Degree', y='Salary', data=filtered_df)

plt.xlabel('Degree')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Degree')

plt.show()

# %% [markdown]
# - Mtech/ME people having more salaries followed by Btech and MCA and MSc

# %% [markdown]
# ### Employees with which specialization having most salaries?

# %%
top_ten_Specialization = df['Specialization'].value_counts().head(10).index

filtered_df = df[df['Specialization'].isin(top_ten_Specialization)]
plt.figure(figsize=(24, 8))

sns.boxplot(x='Specialization', y='Salary', data=filtered_df)
plt.xticks(rotation=45)
plt.xlabel('Specialization')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 10 Specialization')

plt.show()

# %% [markdown]
# - Employees with computer engineering specilization have more salaries
# - Employees with computer application specialization have less salaries

# %% [markdown]
# ### Employees from which college state having more salaries?

# %%
top_ten_CollegeState = df['CollegeState'].value_counts().head(10).index

filtered_df = df[df['CollegeState'].isin(top_ten_CollegeState)]
plt.figure(figsize=(24, 8))

sns.boxplot(x='CollegeState', y='Salary', data=filtered_df)
plt.xticks(rotation=45)
plt.xlabel('CollegeState')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 10 CollegeState')

plt.show()

# %% [markdown]
# - Degree college states like karnataka followed by Madhya Pradesh,Ap have more salries

# %% [markdown]
# # Research Quetions

# %% [markdown]
# ### which state students have more salary

# %%
top_ten_CollegeState = df['CollegeState'].value_counts().head(10).index

filtered_df = df[df['CollegeState'].isin(top_ten_CollegeState)]
plt.figure(figsize=(24, 8))

sns.boxplot(x='CollegeState', y='Salary',hue='Gender' ,data=filtered_df)
plt.xticks(rotation=45)
plt.xlabel('CollegeState')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 10 CollegeState')

plt.show()

# %% [markdown]
# - yes,there is a relationship between gender,College State and salary.Some Collegestate candidates belongs to male have more salary and some female candidates have more salary

# %% [markdown]
# ### which specialization students have more salary

# %%
top_ten_Specialization = df['Specialization'].value_counts().head(10).index

filtered_df = df[df['Specialization'].isin(top_ten_Specialization)]
plt.figure(figsize=(24, 8))

sns.boxplot(x='Specialization', y='Salary',hue='Gender', data=filtered_df)
plt.xticks(rotation=45)
plt.xlabel('Specialization')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 10 Specialization')

plt.show()

# %% [markdown]
# - yes,there is a relationship between gender,specilization and salary.Some specialization candidates belongs to male have more salary and some female candidates have more salary

# %% [markdown]
# ### Times of India article dated Jan 18, 2019 states that “After doing your Computer Science Engineering if you take up jobs as a Programming Analyst, Software Engineer, Hardware Engineer and Associate Engineer you can earn up to 2.5-3 lakhs as a fresh graduate.” Test this claim with the data given to you.

# %%
designations = ['programmer analyst','junior software engineer','hardware engineer','associate engineer']
specialization = ['computer science & engineering']
# Filter the DataFrame to include only rows with these top ten Designations
filtered_designations_df = df[df['Designation'].isin(designations)]

# Get the top five most frequent Specializations
# top_five_specializations = df['Specialization'].value_counts().head(5).index

# Filter the DataFrame to include only rows with these top five Specializations
filtered_df = filtered_designations_df[filtered_designations_df['Specialization'].isin(specialization)]

# print(filtered_df)

# Set the figure size
plt.figure(figsize=(24, 8))

# Create the boxplot
sns.boxplot(x='Specialization', y='Salary', hue='Designation', data=filtered_df)

# Rotate x-axis labels
# plt.xticks(rotation=45)

# Adding x-axis label, y-axis label, and title
plt.xlabel('Specialization')
plt.ylabel('Salary')
plt.title('Boxplot of Salary by Top 5 Specializations and Top 10 Designations')

# Display the plot
plt.show()

# %% [markdown]
# - 2019 data is not available, we have data from 2007 to 2014,so for specialization computer science and engineering, salary is between 2.8 to 3.5 lack for Programmer analyst, associate engineer and junior software  engineer

# %% [markdown]
# ### Is there a relationship between gender and specialization? (i.e. Does the preference of Specialisation depend on the Gender?)

# %%
top_ten_Specializations = df['Specialization'].value_counts().head(10).index

filtered_df = df[df['Specialization'].isin(top_ten_Specializations)]

grouped_data = pd.crosstab(filtered_df['Specialization'], filtered_df['Gender'])

grouped_data_percentage = grouped_data.div(grouped_data.sum(1), axis=0) * 100

ax = grouped_data_percentage.plot(kind='bar', stacked=False, figsize=(20, 6))

plt.title('Percentage of Persons by Specialization and Gender')
plt.xlabel('Specialization')
# plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.legend(title='Gender')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# - yes,there is a relationship between gender and specilization. Irrespective  of specialization male condidates are more than female candidates,

# %% [markdown]
# ### Is there a relationship between gender and CollegeState? (i.e. Does the preference of CollegeState depend on the Gender?)

# %%
top_ten_Specializations = df['CollegeState'].value_counts().head(10).index

filtered_df = df[df['CollegeState'].isin(top_ten_Specializations)]

grouped_data = pd.crosstab(filtered_df['CollegeState'], filtered_df['Gender'])

grouped_data_percentage = grouped_data.div(grouped_data.sum(1), axis=0) * 100

ax = grouped_data_percentage.plot(kind='bar', stacked=False, figsize=(20, 6))

plt.title('Percentage of Persons by CollegeState and Gender')
plt.xlabel('CollegeState')
# plt.ylabel('Percentage')
plt.xticks(rotation=45)
plt.legend(title='Gender')

for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.1f}%', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %% [markdown]
# - yes,there is a relationship between gender and CollegeState. Irrespective  of specialization male condidates are more than female candidates,
